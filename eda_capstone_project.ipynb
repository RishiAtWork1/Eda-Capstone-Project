# %% [markdown]
# #**Exploratory Data Analysis**

# %% [markdown]
# ###**contribution : Individual**
# ###**Project name : Airbnb Booking Analysis**

# %% [markdown]
# # **Problem Statement**
#   ### **Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today Airbnb became one of a kind service that is used and recognised by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. these millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customer's and provider's (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values. Explore and analyse the data to discover key understandings.**
#
# * What can we learn about different hosts and areas?
# * What can we learn from predictions? (ex: locations, prices, reviews, etc)
# * Which hosts are the busiest and why?
# * Is there any noticeable difference of traffic among different areas and what could be the reason for it?

# %% [markdown]
# ***Airbnb (ABNB) is an online marketplace that connects people who want to rent out their homes with people who are looking for accommodations in specific locales.***

# %% [markdown]
# *id = unique id of listing*
#
# *name = name of listing*
#
# *host id = unique host id*
#
# *host name = name of the host*
#
# *neighbourhood group = location*
#
# *neighbourhood = area*
#
# *lattitude = listing lattitude*
#
# *longitude = listing longitude*
#
# *room type = type of listing (entire room, private room, shared room)*
#
# *price = price of listing*
#
# *minimum nights =  the minimum number stay of nights that a guest must require to stay*
#
# *number_of_reviews = number of reviews, it will not be reliable for an individual listing (especially as reviews occasionally vanish from the site), but over a city as a whole it should be a useful metric of traffic.*
#
# *last_review = date of the last review*
#
# *reviews_per_month = insights into frequency of visits of the listing*
#
# *calculated_host_listings_count = total count of listing on airbnb*
#
# *availability_365 = an indicator of the total number of days the listing is available for during the year (i.e. if all the available days are rented out, then the listing's occupancy rate is 100%)*

# %% [markdown]
# **Github link**
#
# https://github.com/RishiAtWork1?tab=repositories

# %% [markdown]
# ###**Import Libraries** and **mount the drive**

# %%
# mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import all the required libraries and modules
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# upload the data using pandas module
airbnb=pd.read_csv('/content/drive/MyDrive/Airbnb NYC 2019.csv')

# %%
# read the first five rows
airbnb.head(10).T
# Out:
#                                                                  0  \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             2018-10-19
# ...

# %%
# estimated revenues
airbnb['revenues'] = airbnb['price']*airbnb['minimum_nights']
airbnb.T
# Out:
#                                                              0      \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             2018-10-19
# ...

# %%
# rows and columns count
airbnb.shape
# Out:
# (48895, 17)

# %%
# Dataset info
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# checking the null value counts
print(airbnb.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# revenues                              0
# dtype: int64

# %% [markdown]
# there are missing / null values in host name, name, last review, reviews per month.

# %%
# check columns in the data
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'revenues'],
#       dtype='object')

# %%
# we will get information about id and host id
print(airbnb['id'].nunique())
print(airbnb['host_id'].nunique())
print(airbnb['host_name'].nunique())
print(airbnb['name'].nunique())
print(airbnb['latitude'].nunique())
print(airbnb['longitude'].nunique())
# Out:
# 48895
# 37457
# 11452
# 47905
# 19048
# 14718

# %% [markdown]
# there are unique id for every listing. there are 37457 host id. each host id is different as per the room type, location.

# %%
# lets check highest listing on airbnb of particular host in particular neighnourhood
Sonder_host = airbnb[airbnb['calculated_host_listings_count']==327]
Sonder_host.T
# Out:
#                                                                         38293  \
# id                                                                   30181691
# name                            Sonder | 180 Water | Incredible 2BR + Rooftop
# host_id                                                             219517861
# host_name                                                        Sonder (NYC)
# neighbourhood_group                                                 Manhattan
# neighbourhood                                              Financial District
# latitude                                                             40.70637
# longitude                                                           -74.00645
# room_type                                                     Entire home/apt
# price                                                                     302
# minimum_nights                                                             29
# ...

# %% [markdown]
# here we can see that **highest listing** is of Sonder(host id-219517861 and calculated host listings count-327) host in **Manhattan neighbourhood group** in **Financial/Theatre District for entire home room type**. **Sonder is the busiest host** as per the listing count as well as the availability of room over the year.

# %%
#let's see some pattern of host name
airbnb[airbnb['host_name']=='John'].T
# Out:
#                                                              0      \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             2018-10-19
# ...

# %% [markdown]
# there is **relation between host_name, host_id and calculated host listings count**. **host_name can be same but but host_id is different**. e.g. John. there are so many host of naming John. but every person having name John get different host_id.
# from this we can conclude that **there can be more than 2 host of naming John**.

# %%
#heatmap of null values
sns.heatmap(airbnb.isnull(), cbar=False);

# %% [markdown]
# here we can say there are much more null values in last reviews and reviews per month.

# %% [markdown]
# ###**Data Cleaning**

# %%
# here we will delete unnecessary column like last reviews,name. because there is no relevance of last reviews and name of listing in our data.
airbnb.drop(['last_review','name'],axis=1,inplace=True)
airbnb.T
# Out:
#                                        0                1             2      \
# id                                      2539             2595          3647
# host_id                                 2787             2845          4632
# host_name                               John         Jennifer     Elisabeth
# neighbourhood_group                 Brooklyn        Manhattan     Manhattan
# neighbourhood                     Kensington          Midtown        Harlem
# latitude                            40.64749         40.75362      40.80902
# longitude                          -73.97237        -73.98377      -73.9419
# room_type                       Private room  Entire home/apt  Private room
# price                                    149              225           150
# minimum_nights                             1                1             3
# number_of_reviews                          9               45             0
# ...

# %%
# here we will replace all missing values in reviews per month with 0
airbnb['reviews_per_month'].fillna(0,inplace=True)
airbnb.T
# Out:
#                                        0                1             2      \
# id                                      2539             2595          3647
# host_id                                 2787             2845          4632
# host_name                               John         Jennifer     Elisabeth
# neighbourhood_group                 Brooklyn        Manhattan     Manhattan
# neighbourhood                     Kensington          Midtown        Harlem
# latitude                            40.64749         40.75362      40.80902
# longitude                          -73.97237        -73.98377      -73.9419
# room_type                       Private room  Entire home/apt  Private room
# price                                    149              225           150
# minimum_nights                             1                1             3
# number_of_reviews                          9               45             0
# ...

# %%
#check if any value is null
airbnb.isnull().sum()
# Out:
# id                                 0
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# revenues                           0
# dtype: int64

# %% [markdown]
# there are 21 host name missing.

# %%
# we will not consider the rows where host name is missing. there will be not much impact on data since percentage of data of host name is negligible
airbnb=airbnb[~airbnb['host_name'].isnull()]
airbnb
# Out:
#              id   host_id      host_name neighbourhood_group  \
# 0          2539      2787           John            Brooklyn
# 1          2595      2845       Jennifer           Manhattan
# 2          3647      4632      Elisabeth           Manhattan
# 3          3831      4869    LisaRoxanne            Brooklyn
# 4          5022      7192          Laura           Manhattan
# ...         ...       ...            ...                 ...
# 48890  36484665   8232441        Sabrina            Brooklyn
# 48891  36485057   6570630        Marisol            Brooklyn
# 48892  36485431  23492952  Ilgar & Aysel           Manhattan
# 48893  36485609  30985759            Taz           Manhattan
# 48894  36487245  68119814     Christophe           Manhattan
#
#             neighbourhood  latitude  longitude        room_type  price  \
# 0              Kensington  40.64749  -73.97237     Private room    149
# 1                 Midtown  40.75362  -73.98377  Entire home/apt    225
# ...

# %%
# describe numerical data
airbnb.describe().astype(int).T
# Out:
#                                 count      mean       std   min      25%  \
# id                              48874  19019875  10983179  2539  9474068
# host_id                         48874  67621569  78614153  2438  7823257
# latitude                        48874        40         0    40       40
# longitude                       48874       -73         0   -74      -73
# price                           48874       152       240     0       69
# minimum_nights                  48874         7        20     1        1
# number_of_reviews               48874        23        44     0        1
# reviews_per_month               48874         1         1     0        0
# calculated_host_listings_count  48874         7        32     1        1
# availability_365                48874       112       131     0        0
# revenues                        48874      1284     11807     0      135
#
#                                      50%        75%        max
# ...

# %% [markdown]
# here **price, minimum nights, number of reviews, reviews per month, calculated host listing count, availability of room during 365 are the numerical data**.
# minimum price is 0 and maximum is 10,000.
# **average price** per listing is 152.
# on an **average people has to stay for 7 days** in a room, and maximum minimum nights is 1250 days. **average number of reviews** is 23 and highest is 629. **average availability of rooms** over the year is 112. **average host listing count is 7** and highest is 327.

# %%
# describe categorical data
airbnb.describe(include='O').T
# Out:
#                      count unique              top   freq
# host_name            48874  11452          Michael    417
# neighbourhood_group  48874      5        Manhattan  21652
# neighbourhood        48874    221     Williamsburg   3919
# room_type            48874      3  Entire home/apt  25400

# %% [markdown]
# from this describe table we can conclude that **host name, neighbourhood group, neighbourhood, room type, are categorical variable**. highest listing is in **Manhattan** neighbourhood group and **Williamsburg** neighbourhood. highest preferences for **Entire home/apt** by customer.

# %%
airbnb.nunique()
# Out:
# id                                48874
# host_id                           37439
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19042
# longitude                         14717
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# reviews_per_month                   938
# calculated_host_listings_count       47
# availability_365                    366
# revenues                           2125
# dtype: int64

# %% [markdown]
# ##**Data Visualization and Grouping**

# %%
# count of neighbourhood
airbnb1 = airbnb.groupby(['neighbourhood_group','neighbourhood']).agg({'id':'count','price':'mean','number_of_reviews':'sum','reviews_per_month':'sum'}).sort_values(by='id',ascending=False)
airbnb1.head(10)
# Out:
#                                           id       price  number_of_reviews  \
# neighbourhood_group neighbourhood
# Brooklyn            Williamsburg        3919  143.802501              85427
#                     Bedford-Stuyvesant  3714  107.678244             110352
# Manhattan           Harlem              2656  119.020708              75927
# Brooklyn            Bushwick            2464   84.819805              52513
# Manhattan           Upper West Side     1970  210.934010              36058
#                     Hell's Kitchen      1955  204.924297              49941
#                     East Village        1853  186.083108              44670
#                     Upper East Side     1797  188.872565              31686
# Brooklyn            Crown Heights       1563  112.520154              36408
# Manhattan           Midtown             1545  282.719094              19444
#
#                                         reviews_per_month
# neighbourhood_group neighbourhood
# ...

# %% [markdown]
# **highest listing** is in **Williamsburg neighbourhood, Brooklyn neighbourhood group**.**2nd highest is also in Brooklyn neighbourhood group** which is **Bedford-Stuyvesant**.and 3rd highest is in **Harlem neighbourhood** Manhattan neighbourhood group. top 10 neighbourhood is in Manhattan and Brooklyn neighbourhood group.

# %%
# sorting of neighbourhood in descending order by number of reviews
airbnb1.sort_values(by='number_of_reviews',ascending=False).head(10)
# Out:
#                                           id       price  number_of_reviews  \
# neighbourhood_group neighbourhood
# Brooklyn            Bedford-Stuyvesant  3714  107.678244             110352
#                     Williamsburg        3919  143.802501              85427
# Manhattan           Harlem              2656  119.020708              75927
# Brooklyn            Bushwick            2464   84.819805              52513
# Manhattan           Hell's Kitchen      1955  204.924297              49941
#                     East Village        1853  186.083108              44670
#                     East Harlem         1116  133.193548              36440
# Brooklyn            Crown Heights       1563  112.520154              36408
# Manhattan           Upper West Side     1970  210.934010              36058
#                     Upper East Side     1797  188.872565              31686
#
#                                         reviews_per_month
# neighbourhood_group neighbourhood
# ...

# %% [markdown]
# here, we can see that **highest number of reviews is of Bedford-Stuyvesant	neighbourhood, and then Williamsburg, Harlem, Bushwick**, etc.

# %%
#grouping of host by their listing
airbnb2 = airbnb.groupby(['calculated_host_listings_count','host_name','host_id']).agg({'revenues':'mean','id':'count'}).sort_values(by='id',ascending=False).head(10)
airbnb2
# Out:
#                                                                 revenues   id
# calculated_host_listings_count host_name         host_id
# 327                            Sonder (NYC)      219517861   2906.584098  327
# 232                            Blueground        107434423   9735.258621  232
# 121                            Kara              30283594    9621.842975  121
# 103                            Kazuya            137358866   1314.757282  103
# 96                             Sonder            12243051    6177.906250   96
#                                Jeremy & Laura    16098958    6268.750000   96
# 91                             Corporate Housing 61391963    4439.670330   91
# 87                             Ken               22541573    6463.103448   87
# 65                             Pranjal           200380610  10220.307692   65
# 52                             Mike              1475015     3092.307692   52

# %% [markdown]
# here we can see that, **highest listing is of Sonder(NYC)-327**,followed by **Blueground(232), then Kara(121),Kazuya(103),Sonder(96)**,etc

# %%
# highest average revenue earning host
airbnb2.sort_values(by='revenues',ascending=False)
# Out:
#                                                                 revenues   id
# calculated_host_listings_count host_name         host_id
# 65                             Pranjal           200380610  10220.307692   65
# 232                            Blueground        107434423   9735.258621  232
# 121                            Kara              30283594    9621.842975  121
# 87                             Ken               22541573    6463.103448   87
# 96                             Jeremy & Laura    16098958    6268.750000   96
#                                Sonder            12243051    6177.906250   96
# 91                             Corporate Housing 61391963    4439.670330   91
# 52                             Mike              1475015     3092.307692   52
# 327                            Sonder (NYC)      219517861   2906.584098  327
# 103                            Kazuya            137358866   1314.757282  103

# %% [markdown]
# from above, we can see that, **Pranjal has highest revenue earning host** whose **listing count is 65** only. followed by Blueground,Kara,Ken,etc

# %%
# check the highest revenue earning host
airbnb1 = airbnb.sort_values(by='revenues',ascending=False)
airbnb1.T
# Out:
#                                           48043         9151   \
# id                                     36056808       7003697
# host_id                               271248669      20582832
# host_name                                 Jenny      Kathrine
# neighbourhood_group                   Manhattan        Queens
# neighbourhood                           Tribeca       Astoria
# latitude                               40.71206       40.7681
# longitude                             -74.00999     -73.91651
# room_type                       Entire home/apt  Private room
# price                                      6500         10000
# minimum_nights                              180           100
# number_of_reviews                             0             2
# reviews_per_month                           0.0          0.04
# calculated_host_listings_count                1             1
# availability_365                            365             0
# ...

# %% [markdown]
# highest revenue earned by one listing and by one visit is of host **Jenny(Manhattan NG, Tribeca N, Entire home) the Kathrine(Queens NG, Astoria neighbourhood,private room), etc**. here we can see that minimum nights is more than 100 days means **these host wanted to rent out room for long term only**.also we can see that the prices is much higher. but reviews per month is much lower, so we conclude that the **frequency of visits is much less**.

# %%
# highest prices
airbnb[airbnb['price']==10000]
# Out:
#              id   host_id host_name neighbourhood_group    neighbourhood  \
# 9151    7003697  20582832  Kathrine              Queens          Astoria
# 17692  13894339   5143901      Erin            Brooklyn       Greenpoint
# 29238  22436899  72390391    Jelena           Manhattan  Upper West Side
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 9151   40.76810  -73.91651     Private room  10000             100
# 17692  40.73260  -73.95739  Entire home/apt  10000               5
# 29238  40.77213  -73.98665  Entire home/apt  10000              30
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 9151                   2               0.04                               1
# 17692                  5               0.16                               1
# 29238                  0               0.00                               1
#
#        availability_365  revenues
# 9151                  0   1000000
# ...

# %% [markdown]
# highest price among the host is of **Kathrine(Queens NG, Astoria N, private room), Erin(Brooklyn NG, Greenpoint N, entire home/apt), Jelena(Manhattan NG, Upper West Side N, entire home/apt)**.

# %%
# to see the reviews per month(frequency of visits per month)
airbnb1 = airbnb.sort_values(by='reviews_per_month',ascending=False)
airbnb1.head(5)
# Out:
#              id    host_id host_name neighbourhood_group        neighbourhood  \
# 42075  32678719  244361589   Row NYC           Manhattan     Theater District
# 42076  32678720  244361589   Row NYC           Manhattan     Theater District
# 38870  30423106  228415932    Louann              Queens             Rosedale
# 27287  21550302  156684502   Nalicia              Queens  Springfield Gardens
# 28651  22176831  156684502   Nalicia              Queens  Springfield Gardens
#
#        latitude  longitude     room_type  price  minimum_nights  \
# 42075  40.75918  -73.98801  Private room    100               1
# 42076  40.75828  -73.98876  Private room    199               1
# 38870  40.65417  -73.74158  Private room     45               1
# 27287  40.66110  -73.76830  Private room     80               1
# 28651  40.66158  -73.77050  Private room     50               1
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %% [markdown]
# here we can that, whose **reviews per month is high** i.e. the frequency of visit is highest has **less minimum night stay requirement**.we can see that, **price is much less whose reviews per month is high**.

# %%
# graphical distribution of reviews per month
plt.figure(figsize=(18,6))
plt.title('insights on frequency of visits of listing by reviews per month')
sns.barplot(data=airbnb1.head(30),x='host_name',y='reviews_per_month',hue='neighbourhood_group');

# %% [markdown]
# here we can see that **Row NYC host has the highest frequency of visits of listing**. after that Louann, Nalicia, Danielle,etc have the highest frequency of visits of listing.

# %%
manhattan_airbnb = airbnb[(airbnb['neighbourhood_group']=='Manhattan') & (airbnb['revenues']>=10000)].sort_values(by='revenues',ascending=False).head(10)
brooklyn_airbnb = airbnb[(airbnb['neighbourhood_group']=='Brooklyn') & (airbnb['revenues']>=10000)].sort_values(by='revenues',ascending=False).head(10)
queens_airbnb = airbnb[(airbnb['neighbourhood_group']=='Queens') & (airbnb['revenues']>=10000)].sort_values(by='revenues',ascending=False).head(10)
bronx_airbnb = airbnb[(airbnb['neighbourhood_group']=='Bronx') & (airbnb['revenues']>=5000)].sort_values(by='revenues',ascending=False).head(10)
staten_island_airbnb = airbnb[(airbnb['neighbourhood_group']=='Staten Island') & (airbnb['revenues']>=5000)].sort_values(by='revenues',ascending=False).head(10)

# %%
fig,axes =plt.subplots(3,2,figsize=(20,12))

axes[0,0].set_title('highest revenue earning host in manhattan group')
sns.barplot(x=manhattan_airbnb.host_name,y=manhattan_airbnb.revenues,hue=manhattan_airbnb.room_type,ax=axes[0,0])

axes[0,1].set_title('highest revenue earning host in brooklyn group')
sns.barplot(x=brooklyn_airbnb.host_name,y=brooklyn_airbnb.revenues,hue=brooklyn_airbnb.room_type,ax=axes[0,1])

axes[1,0].set_title('highest revenue earning host in queens group')
sns.barplot(x=queens_airbnb.host_name,y=queens_airbnb.revenues,hue=queens_airbnb.room_type,ax=axes[1,0])

axes[1,1].set_title('highest revenue earning host in bronx group')
sns.barplot(x=bronx_airbnb.host_name,y=bronx_airbnb.revenues,hue=bronx_airbnb.room_type,ax=axes[1,1])

axes[2,0].set_title('highest revenue earning host in staten island group')
sns.barplot(x=staten_island_airbnb.host_name,y=staten_island_airbnb.revenues,hue=staten_island_airbnb.room_type,ax=axes[2,0])

axes[2,1].set_title('revenues earning distribution by neighbourhood group')  #highest revenue earning neighbourhood group
sns.barplot(x=airbnb['neighbourhood_group'],y=airbnb['revenues'],ax=axes[2,1])

plt.tight_layout(pad=1)

# %% [markdown]
# * highest revenue earned **by one visit and by one listing is of Jenny, Amy, Peter, Adam, Jelena, etc in Manhattan NG**.
# * highest revenue earned **by one visit and by one listing is of Jeffrey, Mark, Adela etc in Brooklyn NG**
# * highest revenue earned **by one visit and by one listing is of Kathrine,Iveta,Noelle etc in Queens NG**.
# * highest revenue earned **by one visit and by one listing is of Vicdania, John, Sasha etc in Bronx NG**.
# * highest revenue earned **by one visit and by one listing is of Janine, Anastasios,Mary,Mark etc in Staten Island NG**.
# * highest revenue is earned by the neighbourhood group Manhatten.we can conclude that **Manhattan** area is much **crowdy** or **most demanded location**. and least by Bronx neighbourhood group.

# %%
# vizualization of number pf reviews, price, availability of rooms over the year, minimum nights
fig,axes =plt.subplots(2,2,figsize=(20,10))

axes[0,0].set_title('distribution of room type by the availability of rooms over the year')
sns.barplot(x=airbnb.room_type,y=airbnb.availability_365,hue=airbnb.neighbourhood_group,ax=axes[0,0]) # availability of rooms over the year in different neighbourhood group

axes[0,1].set_title('distribution of room type by number of reviews')
sns.barplot(x=airbnb.room_type,y=airbnb.number_of_reviews,hue=airbnb.neighbourhood_group,ax=axes[0,1]) # number of reviews by room type in different neighbourhood group

axes[1,0].set_title('distribution of room type by prices')
sns.barplot(x=airbnb.room_type,y=airbnb.price,hue=airbnb.neighbourhood_group,ax=axes[1,0]) # variation of price by room type in different neighbourhood group

axes[1,1].set_title('distribution of room type by minimum nights')
sns.barplot(x=airbnb.room_type,y=airbnb.minimum_nights,hue=airbnb.neighbourhood_group,ax=axes[1,1]) # variation of night by room type in different neighbourhood group

plt.tight_layout(pad=1)

# %% [markdown]
# * ***table 1*** : **highest average availability of room over the year is for Private room(Staten Island NG)**. 2nd highest average is of shared room(Queens NG). and **least average availability of room and highest deviation among data is for shared room(Staten Island)**.
# *  ***table 2*** : the average **highest number of reviews is of Staten Island(Entire home)**. and 2nd highest average is of Bronx(Entire home) neighbourhood group.
# * ***table 3*** : in every room type, average **highest price** is of **Manhattan neighbourhood group**. and **highest price** is of **entire home** followed by private and share room. highest **variation of prices** is in **Staten Island neighbourhood group for entire home**.
# * ***table 4*** : here we can see **highest average minimum nights** is in the **Manhatten neighbourhood group** of entire home room type. **highest variation in the minimum nights** can be seen in **Manhatten neighbourhood group** of **share room type**.

# %%
#let's count the listing of different neighbourhood group
plt.figure(figsize=(13,7))
plt.title("Room Type on Neighbourhood Group")
sns.countplot(x=airbnb['neighbourhood_group'],hue=airbnb['room_type'])
plt.show();

# %% [markdown]
# **highest listing is in Manhattan(for entire home)** neighbourhood group followed by Brooklyn(for private room).

# %%
#lets count the availability of room over the year
entire_room = airbnb[airbnb['room_type']=='Entire home/apt']
private_room = airbnb[airbnb['room_type']=='Private room']
share_room = airbnb[airbnb['room_type']=='Shared room']

plt.figure(figsize=(13,7))
plt.title("count of availability of rooms over the year")
plt.hist(entire_room.availability_365,bins=20,alpha=0.5)
plt.hist(private_room.availability_365,bins=20,alpha=0.5)
plt.hist(share_room.availability_365,bins=20,alpha=0.5)
plt.legend(['entire room','private room','share room'])


plt.show();

# %% [markdown]
# here we can see that there is much less availability of room. **most of the listings are available only for 0-20 days** by host for booking.

# %%
# distribution of neighbourhood group and neighbourhood along lattitude and longitude
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.scatterplot(data=airbnb['neighbourhood_group'],x=airbnb['longitude'],y=airbnb['latitude'],hue=airbnb['neighbourhood_group']);

plt.subplot(1,2,2)
x = sns.scatterplot(data=airbnb['neighbourhood'],x=airbnb['longitude'],y=airbnb['latitude'],hue=airbnb['neighbourhood']);
x.legend_ = None

plt.show()

# %% [markdown]
# here the **wide distribution** is of **Queens neighbourhood group** which lies between lattitude range of 40.8 to 40.55 and longitude range of -74.0 to -73.7.

# %%
#distribution and frequency of prices in different region
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.title('distribution of price between the range of 0 to 1000')
sns.scatterplot(x=airbnb.longitude,y=airbnb.latitude,hue=airbnb[airbnb['price']<=1000].price,s=20)
plt.subplot(1,2,2)
plt.title('distribution of price between the range of 1000 to 10000')
sns.scatterplot(x=airbnb.longitude,y=airbnb.latitude,hue=airbnb[airbnb['price']>=1000].price,s=20)

plt.show()

# %% [markdown]
# here we can see that **highest frequency of listing is in price range of 0 to 1000**. **least frequency** is in the **price range of 1000 to 10000**.

# %%
#correlation between different attributes
corr = airbnb.corr(method='kendall')
plt.figure(figsize=(13,10))
plt.title("Correlation Between Different Variables")
sns.heatmap(corr, annot=True)
plt.show()
# Out:
# <ipython-input-36-6b96145a9ec8>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = airbnb.corr(method='kendall')

# %% [markdown]
# here the **highest correlation is between the number of reviews and reviews per month**. followed by revenues and minimum nights. and revenues and price.

# %%
# boxplot for price between 100 to 2000
price_above_100 = airbnb[(airbnb['price']>=100)&(airbnb['price']<=2000)]
plt.figure (figsize= (10,10))
ax= sns.boxplot(data=price_above_100,x='neighbourhood_group',y='price',palette='plasma')

# %% [markdown]
# **in prices range** there is **no limit of fixation of the prices by airbnb**. hence **there are so many outliers occured in the prices**.

# %%
categorical_data = airbnb[['id','host_name','number_of_reviews','neighbourhood_group','neighbourhood','price','room_type','minimum_nights','availability_365','reviews_per_month']].sort_values('minimum_nights',ascending=False)
categorical_data.head(5)
# Out:
#              id  host_name  number_of_reviews neighbourhood_group  \
# 5767    4204302  Genevieve                  2           Manhattan
# 2854    1615764      Peter                  0           Manhattan
# 38664  30378211        Meg                  0           Manhattan
# 26341  20990053      Angie                 24            Brooklyn
# 13404  10053943   Glenn H.                  2           Manhattan
#
#            neighbourhood  price        room_type  minimum_nights  \
# 5767   Greenwich Village    180  Entire home/apt            1250
# 2854   Battery Park City    400  Entire home/apt            1000
# 38664  Greenwich Village    110      Shared room             999
# 26341       Williamsburg     79     Private room             999
# 13404             Harlem     99  Entire home/apt             999
#
#        availability_365  reviews_per_month
# 5767                365               0.03
# 2854                362               0.00
# 38664               365               0.00
# ...

# %%
plt.figure(figsize=(18,6))
plt.title('highest minimum nights stay requirement by host name')
sns.barplot(data=categorical_data.head(20),x='host_name',y='minimum_nights',hue='neighbourhood_group');

# %% [markdown]
# highest minimum nights is of **listing id-4204302** in the **Manhattan NG and Greenwitch Village Neighbourhood** rented by the host **Genevieve** also **availability** of that particular **entire home** is **over the year**. here **Genevieve, Peter, Meg, Angie, etc are those host who only want to attract only long term guests**. here we can see from reviews per month that the **frequency of visits of listing is less for long term minimum nights**. also the number of reviews is also less for long term minimum nights.

# %%
plt.figure(figsize=(12,12))
categorical_data = airbnb[['number_of_reviews','neighbourhood_group','price','room_type','minimum_nights','availability_365','reviews_per_month']]
sns.pairplot(categorical_data,hue='room_type');

# %% [markdown]
#  * **no_of_reviews vs price :** we can see from above pairplot that as the price increases number of reviews decreases. and the **lower price = higher number of reviews**. **highest number of reviews** are getting by the listing whose **price range is between 0-1000$**. also **highest number of reviews is getting by the listing of private room type**.
#  * **minimum_nights vs availability_365 :** most of host set minimum nights stay for 2-200 days in the particular year.
#  * **no_of_reviews vs minimum_nights :** **most of the number of reviews** are from those whose **minimum night stay is for 0-100 nights**. we can see as we go upper along the minimum night axis it is begining to diminished. also we can say that most host prefer to **rent out their property for long term**.
#  * **minimum_nights vs price:** most host whose requirement of minimum night is high they prefer to put less price range.
#  * **reviews per month vs price:** we can see that, highest frequency of visit i.e. high reviews per month = where there is less price
#  * **reviews per month vs minimum nights:** from above scatter plot, we can see, highest frequency of visits i.e. high reviews per month = where there is less minimum nights stay requirement.

# %% [markdown]
# #**Conclusion**
#
#  * **highest listing** is in **Williamsburg neighbourhood, Brooklyn neighbourhood group**.**2nd highest is also in Brooklyn neighbourhood group** which is **Bedford-Stuyvesant**.and 3rd highest is in **Harlem neighbourhood** Manhattan neighbourhood group. top 10 neighbourhood is in Manhattan and Brooklyn neighbourhood group.
#  * here we can see that, **highest listing is of Sonder(NYC)-327**,followed by **Blueground(232), then Kara(121),Kazuya(103),Sonder(96)**,etc
#  * **Pranjal has highest revenue earning host** whose **listing count is 65** only. followed by Blueground,Kara,Ken,etc
#  * highest revenue earned by one listing and by one visit is of host **Jenny(Manhattan NG, Tribeca N, Entire home) the Kathrine(Queens NG, Astoria neighbourhood,private room), etc**.minimum nights is more than 100 days means **these host wanted to rent out room for long term only**.also we can see that the prices is much higher. but reviews per month is much lower, so we conclude that the **frequency of visits is much less**.
#  * highest price among the host is of **Kathrine(Queens NG, Astoria N, private room), Erin(Brooklyn NG, Greenpoint N, entire home/apt), Jelena(Manhattan NG, Upper West Side N, entire home/apt)**.
#  * **Row NYC host has the highest frequency of visits of listing**. after that Louann, Nalicia, Danielle,etc have the highest frequency of visits of listing.whose **reviews per month is high** i.e. the frequency of visit is highest has **less minimum night stay requirement**.we can see that, **price is much less whose reviews per month is high**.
#  * * highest revenue earned **by one visit and by one listing is of Jenny, Amy, Peter, Adam, Jelena, etc in Manhattan NG**.
#    * highest revenue earned **by one visit and by one listing is of Jeffrey, Mark, Adela etc in Brooklyn NG**
#    * highest revenue earned **by one visit and by one listing is of Kathrine,Iveta,Noelle etc in Queens NG**.
#    * highest revenue earned **by one visit and by one listing is of Vicdania, John, Sasha etc in Bronx NG**.
#    * highest revenue earned **by one visit and by one listing is of Janine, Anastasios,Mary,Mark etc in Staten Island NG**.
#    * highest revenue is earned by the neighbourhood group Manhatten.we can conclude that **Manhattan** area is much **crowdy** or **most demanded location**. and least by Bronx neighbourhood group.
#  * * **highest average availability of room over the year is for Private room(Staten Island NG)**. 2nd highest average is of shared room(Queens NG). and **least average availability of room and highest deviation among data is for shared room(Staten Island)**.
#    * the average **highest number of reviews is of Staten Island(Entire home)**. and 2nd highest average is of Bronx(Entire home) neighbourhood group.
#    * in every room type, average **highest price** is of **Manhattan neighbourhood group**. and **highest price** is of **entire home** followed by private and share room. highest **variation of prices** is in **Staten Island neighbourhood group for entire home**.
#    * here we can see **highest average minimum nights** is in the **Manhatten neighbourhood group** of entire home room type. **highest variation in the minimum nights** can be seen in **Manhatten neighbourhood group** of **share room type**.
#  * **highest listing is in Manhattan(for entire home)** neighbourhood group followed by Brooklyn(for private room). and less listing is in Bronx and Staten Island neighbourhood group and also for shared room type.
#  *  **most of the listings are available only for 0-20 days** by host for booking.
#  *  **highest frequency of listing is in price range of 0 to 1000**. **least frequency** is in the **price range of 1000 to 10000**.
#  * **highest correlation is between the number of reviews and reviews per month**. followed by revenues and minimum nights. and revenues and price.
#  * **in prices range** there is **no limit of fixation of the prices by airbnb**. hence **there are so many outliers occured in the prices**.
#  * highest minimum nights is of **listing id-4204302** in the **Manhattan NG and Greenwitch Village Neighbourhood** rented by the host **Genevieve** also **availability** of that particular **entire home** is **over the year**. here **Genevieve, Peter, Meg, Angie, etc are those host who only want to attract only long term guests**. here we can see from reviews per month that the **frequency of visits of listing is less for long term minimum nights**. also the number of reviews is also less for long term minimum nights.
#  * * **no_of_reviews vs price :** we can see from above pairplot that as the price increases number of reviews decreases. and the **lower price = higher number of reviews**. **highest number of reviews** are getting by the listing whose **price range is between 0-1000$**. also **highest number of reviews is getting by the listing of private room type**.
#    * **minimum_nights vs availability_365 :** most of host set minimum nights stay for 2-200 days in the particular year.
#    * **no_of_reviews vs minimum_nights :** **most of the number of reviews** are from those whose **minimum night stay is for 0-100 nights**. we can see as we go upper along the minimum night axis it is begining to diminished. also we can say that most host prefer to **rent out their property for long term**.
#    * **minimum_nights vs price:** most host whose requirement of minimum night is high they prefer to put less price range.
#    * **reviews per month vs price:** we can see that, highest frequency of visit i.e. high reviews per month = where there is less price
#   * **reviews per month vs minimum nights:** highest frequency of visits i.e. high reviews per month = where there is less minimum nights stay requirement.
